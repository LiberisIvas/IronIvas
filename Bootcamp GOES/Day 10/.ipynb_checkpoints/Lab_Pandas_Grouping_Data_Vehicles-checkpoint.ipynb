# %% [markdown]
# # Pandas: grouping

# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("vehicles.csv")

# %%
cars.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# How many Car models?

# %%
cars.Model.nunique()
# Out:
# 3608

# %% [markdown]
# group by the data by the Make  using count function

# %%
cars.groupby('Make').count()
# Out:
#                              Model  Year  Engine Displacement  Cylinders  \
# Make
# AM General                       4     4                    4          4
# ASC Incorporated                 1     1                    1          1
# Acura                          302   302                  302        302
# Alfa Romeo                      41    41                   41         41
# American Motors Corporation     22    22                   22         22
# ...                            ...   ...                  ...        ...
# Volkswagen                    1047  1047                 1047       1047
# Volvo                          717   717                  717        717
# Wallace Environmental           32    32                   32         32
# Yugo                             8     8                    8          8
# smart                           20    20                   20         20
#
#                              Transmission  Drivetrain  Vehicle Class  \
# Make
# ...

# %% [markdown]
# What brand has the most cars?

# %%
cars.groupby("Make").Model.count().idxmax()
# Out:
# 'Chevrolet'

# %%
cars.groupby("Make").Model.nunique().idxmax()
# Out:
# 'Mercedes-Benz'

# %%
cars["Combined KPL"] = round(cars["Combined MPG"] * 1.609/3.785 , 2)
cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
cars['CO2 Emission Grams/Km'] = round(cars['CO2 Emission Grams/Mile'] / 1.609, 2)
cars['Highway Km'] = round(cars['Highway MPG'] * 1.609/3.785, 2)
cars['City Km'] = round(cars['City MPG'] * 1.609/3.785, 2)
cars['Combined Km'] = round(cars['Combined MPG'] * 1.609/3.785, 2)
cars['CO2 Emission Grams/Km'] = round(cars['CO2 Emission Grams/Mile'] , 2)

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand
#
# ### your code us here

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand ... sorted

# %%
cars.groupby('Make').apply(lambda s:s['CO2 Emission Grams/Km'].mean())
# Out:
# Make
# AM General                     611.360000
# ASC Incorporated               555.440000
# Acura                          422.584967
# Alfa Romeo                     463.951463
# American Motors Corporation    505.756364
#                                   ...
# Volkswagen                     392.740850
# Volvo                          435.803166
# Wallace Environmental          657.993125
# Yugo                           356.068750
# smart                          247.030000
# Length: 127, dtype: float64

# %%
cars.groupby('Make')['CO2 Emission Grams/Km'].mean().sort_values()
# Out:
# Make
# Fisker                                 169.000000
# smart                                  247.030000
# Fiat                                   304.666512
# Daihatsu                               310.187647
# MINI                                   313.716781
#                                          ...
# Laforza Automobile Inc                 807.910000
# Bugatti                                873.062500
# Superior Coaches Div E.p. Dutton       888.700000
# S and S Coach Company  E.p. Dutton     888.700000
# Vector                                1049.160000
# Name: CO2 Emission Grams/Km, Length: 127, dtype: float64

# %%
cars['Transmission'] = list( map(lambda x: "Automatic" if ("Auto" in x) else "Manual",cars['Transmission']) )

# %%
new_cars = cars.to_csv("new_cars.csv")

# %% [markdown]
# Use `pd.cut` or `pd.qcut` to create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
cars['Decade'] = pd.cut(cars['Year'],bins=4,labels=['80s','90s','00s','10s'])
cars.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders Transmission        Drivetrain                Vehicle Class  \
# 0        4.0    Automatic     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0    Automatic     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0    Automatic  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0    Automatic  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0    Automatic  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  ...  Highway MPG  Combined MPG  \
# ...

# %%
newcars = pd.read_csv("new_cars.csv")
newcars.head()
# Out:
#    Unnamed: 0              Make                Model  Year  \
# 0           0        AM General    DJ Po Vehicle 2WD  1984
# 1           1        AM General     FJ8c Post Office  1984
# 2           2        AM General  Post Office DJ5 2WD  1985
# 3           3        AM General  Post Office DJ8 2WD  1985
# 4           4  ASC Incorporated                  GNX  1987
#
#    Engine Displacement  Cylinders Transmission        Drivetrain  \
# 0                  2.5        4.0    Automatic     2-Wheel Drive
# 1                  4.2        6.0    Automatic     2-Wheel Drive
# 2                  2.5        4.0    Automatic  Rear-Wheel Drive
# 3                  4.2        6.0    Automatic  Rear-Wheel Drive
# 4                  3.8        6.0    Automatic  Rear-Wheel Drive
#
#                  Vehicle Class Fuel Type  ...  City MPG  Highway MPG  \
# 0  Special Purpose Vehicle 2WD   Regular  ...        18           17
# 1  Special Purpose Vehicle 2WD   Regular  ...        13           13
# ...

# %%
cars['Year'].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %%
## your code here

# %% [markdown]
# ### Did cars consume more gas in the eighties?

# %% [markdown]
# show the average City_Km/Liter by year_range

# %%
cars.groupby(["Decade"])[['Decade',"City Km"]].mean("City Km")
# Out:
#          City Km
# Decade
# 80s     7.306361
# 90s     7.221697
# 00s     7.122323
# 10s     8.201827

# %% [markdown]
# Which brands are more environment friendly?

# %%
cars.groupby(["Decade","Make"])[["CO2 Emission Grams/Km"]].mean("CO2_Emission_Grams/Km")
# Out:
#                                     CO2 Emission Grams/Km
# Decade Make
# 80s    AM General                              611.360000
#        ASC Incorporated                        555.440000
#        Acura                                   432.104054
#        Alfa Romeo                              461.421429
#        American Motors Corporation             505.756364
# ...                                                   ...
# 10s    Volkswagen                              353.155015
#        Volvo                                   403.025337
#        Wallace Environmental                          NaN
#        Yugo                                           NaN
#        smart                                   247.048889
#
# [508 rows x 1 columns]

# %% [markdown]
# Does the drivetrain affect fuel consumption?

# %%
cars.groupby("Drivetrain")[["Highway Km","City Km"]].mean().sort_values("City Km",ascending=False)
# Out:
#                             Highway Km    City Km
# Drivetrain
# 2-Wheel Drive, Front         14.030000  10.630000
# Front-Wheel Drive            12.164473   9.001822
# All-Wheel Drive              10.881471   7.785204
# 4-Wheel Drive                 9.667949   7.190860
# 2-Wheel Drive                 8.222175   6.642813
# Rear-Wheel Drive              9.023172   6.557019
# 4-Wheel or All-Wheel Drive    8.346717   6.392536
# Part-time 4-Wheel Drive       8.115759   6.216709

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
cars.groupby("Transmission")[["City Km"]].mean().sort_values("City Km",ascending=False)
# Out:
#                City Km
# Transmission
# Manual        7.968305
# Automatic     7.278445

# %% [markdown]
# Use `groupby` and `aggregate` with different aggregation measures for different columns:

# %% [markdown]
# aggregate with average City_Km/Liter and the count of the Trans

# %%
# cars.groupby('Transmission').agg({'City Km':['min', 'max']})
cars.groupby("Transmission").aggregate({"City Km":['mean','count']})
# Out:
#                City Km
#                   mean  count
# Transmission
# Automatic     7.278445  24290
# Manual        7.968305  11662

# %% [markdown]
# aggregate with average City_Km/Liter and the minimum of the Trans

# %%
cars.groupby("Transmission").aggregate({"City Km":['mean','min']})
# Out:
#                City Km
#                   mean   min
# Transmission
# Automatic     7.278445  2.98
# Manual        7.968305  2.55
